# %%
import pandas as pd

# %%
df = pd.read_excel("updated_car1.xlsx")

# %%
df
# Out:
#        Year                   Make/Model    Male  Female  Unknown    Total  \
# 0      2013                   FORD FOCUS  814172  422731    56487  1293390
# 1      2013                  FORD FIESTA  554879  631666    54057  1240602
# 2      2013               VAUXHALL CORSA  458979  562466    47108  1068553
# 3      2013               VAUXHALL ASTRA  600677  322244    40792   963713
# 4      2013              VOLKSWAGEN GOLF  483216  310604    47563   841383
# ...     ...                          ...     ...     ...      ...      ...
# 34629  1994                VOLKSWAGEN TL       0       1        0        1
# 34630  1994                    VOLVO C70       1       0        0        1
# 34631  1994                    VOLVO S40       1       0        0        1
# 34632  1994            W+E Model Missing       1       0        0        1
# 34633  1994  WHITLOCK BROS Model Missing       1       0        0        1
#
# ...

# %%
df.drop_duplicates(inplace=True)

# %%
df
# Out:
#        Year                   Make/Model    Male  Female  Unknown    Total  \
# 0      2013                   FORD FOCUS  814172  422731    56487  1293390
# 1      2013                  FORD FIESTA  554879  631666    54057  1240602
# 2      2013               VAUXHALL CORSA  458979  562466    47108  1068553
# 3      2013               VAUXHALL ASTRA  600677  322244    40792   963713
# 4      2013              VOLKSWAGEN GOLF  483216  310604    47563   841383
# ...     ...                          ...     ...     ...      ...      ...
# 34629  1994                VOLKSWAGEN TL       0       1        0        1
# 34630  1994                    VOLVO C70       1       0        0        1
# 34631  1994                    VOLVO S40       1       0        0        1
# 34632  1994            W+E Model Missing       1       0        0        1
# 34633  1994  WHITLOCK BROS Model Missing       1       0        0        1
#
# ...

# %%
df.dropna(inplace=True)

# %%
df
# Out:
#        Year  Make/Model    Male  Female  Unknown   Total    Male.1  Female.1  \
# 20     2013     AUDI A4  202037   59936    13629  275602  0.733075  0.217473
# 23     2013     AUDI A3  144962   97033    14460  256455  0.565253  0.378363
# 30     2013  CITROEN C3   78551   98254     9893  186698  0.420738  0.526272
# 42     2013    FIAT 500   30349  102113     8177  140639  0.215794  0.726065
# 45     2013  CITROEN C4   79604   42130     5547  127281  0.625419  0.331000
# ...     ...         ...     ...     ...      ...     ...       ...       ...
# 34288  1994   VOLVO 142       7       3        2      12  0.583333  0.250000
# 34339  1994      BMW M1       5       1        1       7  0.714286  0.142857
# 34511  1994     AUDI A4       1       0        0       1  1.000000  0.000000
# 34630  1994   VOLVO C70       1       0        0       1  1.000000  0.000000
# 34631  1994   VOLVO S40       1       0        0       1  1.000000  0.000000
#
# ...
