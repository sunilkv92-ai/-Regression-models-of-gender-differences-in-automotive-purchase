# %%
import pandas as pd

# %%
df = pd.read_excel("car.xlsx")

# %%
df
# Out:
#        Year                   Make/Model    Male  Female  Unknown    Total  \
# 0      2013                   FORD FOCUS  814172  422731    56487  1293390
# 1      2013                  FORD FIESTA  554879  631666    54057  1240602
# 2      2013               VAUXHALL CORSA  458979  562466    47108  1068553
# 3      2013               VAUXHALL ASTRA  600677  322244    40792   963713
# 4      2013              VOLKSWAGEN GOLF  483216  310604    47563   841383
# ...     ...                          ...     ...     ...      ...      ...
# 34629  1994                VOLKSWAGEN TL       0       1        0        1
# 34630  1994                    VOLVO C70       1       0        0        1
# 34631  1994                    VOLVO S40       1       0        0        1
# 34632  1994            W+E Model Missing       1       0        0        1
# 34633  1994  WHITLOCK BROS Model Missing       1       0        0        1
#
#          Male.1  Female.1  Unknown.1
# ...

# %%
pf = pd.read_csv("merged.csv")

# %%
pf
# Out:
#                                     name                  highway  \
# 0                             RIVIAN R1S       121.1 in (3076 mm)
# 1            RIVIAN R1S 105 KWh (408 HP)       121.1 in (3076 mm)
# 2            RIVIAN R1S 135 KWh (764 HP)       121.1 in (3076 mm)
# 3            RIVIAN R1S 180 KWh (710 HP)       135.8 in (3449 mm)
# 4                             RIVIAN R1T       135.8 in (3449 mm)
# ...                                  ...                      ...
# 20346   TESLA MOTORS Model S 60 (380 HP)              245/45 R19
# 20347   TESLA MOTORS Model S 70 (387 HP)              245/45 R19
# 20348  TESLA MOTORS Model S 70D (525 HP)   265/45R20 || 275/45R20
# 20349   TESLA MOTORS Model S 85 (380 HP)  265/45R20 || 275/45R20
# 20350  TESLA MOTORS Model S 85D (376 HP)  265/45R20 || 275/45R20
#
#              displacement           tiresize           wheelbase  \
# 0         8.1 in (206 mm)  11.7 cuFT (331 L)  5842 lbs (2650 kg)
# ...

# %%
df['Highway'] = ""
df['Displacement'] = ""
df['Tiresize'] = ""
df['Wheelbase'] = ""
df['GroundClearance'] = ""
df['Cargo'] = ""
df['Weight'] = ""

# %%
df
# Out:
#        Year                   Make/Model    Male  Female  Unknown    Total  \
# 0      2013                   FORD FOCUS  814172  422731    56487  1293390
# 1      2013                  FORD FIESTA  554879  631666    54057  1240602
# 2      2013               VAUXHALL CORSA  458979  562466    47108  1068553
# 3      2013               VAUXHALL ASTRA  600677  322244    40792   963713
# 4      2013              VOLKSWAGEN GOLF  483216  310604    47563   841383
# ...     ...                          ...     ...     ...      ...      ...
# 34629  1994                VOLKSWAGEN TL       0       1        0        1
# 34630  1994                    VOLVO C70       1       0        0        1
# 34631  1994                    VOLVO S40       1       0        0        1
# 34632  1994            W+E Model Missing       1       0        0        1
# 34633  1994  WHITLOCK BROS Model Missing       1       0        0        1
#
# ...
