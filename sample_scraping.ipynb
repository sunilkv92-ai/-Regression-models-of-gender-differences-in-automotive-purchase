# %%
import requests
import requests
from bs4 import BeautifulSoup
import re

# %%
url = "https://autospecs.org/car-details?cIndex=0"  
r = requests.get(url)
print(r.content)
# Out:
# b'<!DOCTYPE html><html><head><meta charSet="utf-8"/><meta name="google-site-verification" content="CqzA6u2wQ3PzGyUul46JODh760u98Ko8c953yRt0zjA"/><meta name="viewport" content="width=device-width, initial-scale=1.0"/><title>AutoSpecs - Technical specs, cars data and fuel consumption</title><meta name="description" content="Car technical specifications, data, dimensions and fuel consumption information for all car brands and models."/><meta name="keywords" content="cars, engines, fuel, consumption, car specs, fuel economy"/><link rel="icon" href="https://autospecs.org/logo.png"/><link rel="stylesheet" href="https://stackpath.bootstrapcdn.com/bootstrap/4.4.1/css/bootstrap.min.css" integrity="sha384-Vkoo8x4CGsO3+Hhxv8T/Q5PaXtkKtu6ug5TOeNV6gBiFeWPGFN9MuhOf23Q9Ifjh" crossorigin="anonymous"/><link href="https://fonts.googleapis.com/css?family=Roboto+Condensed:300,400,700&amp;display=swap" rel="stylesheet"/><meta name="next-head-count" content="9"/><link rel="preload" href="/_next/static/ByATm9CjPUJ-GpX8lbSIq/pages/car-details.js" as="script"/><link rel="preload" href="/_next/static/ByATm9CjPUJ-GpX8lbSIq/pages/_app.js" as="script"/><link rel="preload" href="/_next/static/runtime/webpack-08f7b238829422e3b9b2.js" as="script"/><link rel="preload" href="/_next/static/chunks/commons.16d6e18a9953cc963322.js" as="script"/><link rel="preload" href="/_next/static/runtime/main-1f8f7ad02e709ded68eb.js" as="script"/><style id="__jsx-4010602164">.compare-models-holder.jsx-4010602164{position:fixed;margin:10px 0 10px 0;height:55px;width:49%;z-index:10000;top:0;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;}@media only screen and (max-width:768px){.compare-models-holder.jsx-4010602164{width:100%;}}</style><style id="__jsx-4034635363">.jsx-4034635363{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:row;-ms-flex-direction:row;flex-direction:row;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;cursor:pointer;}.left-content.jsx-4034635363{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:row;-ms-flex-direction:row;flex-direction:row;}img.jsx-4034635363{height:13px;margin-right:10px;}span.jsx-4034635363{font-family:Roboto Condensed,sans-serif;}.left-content.jsx-4034635363 .jsx-4034635363{font-weight:700;font-size:19px;}.jsx-4034635363:nth-child(2){font-weight:400;font-size:17px;}@media only screen and (max-width:768px){.jsx-4034635363{-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;}}</style><style id="__jsx-3520978155">.card-details-holder.jsx-3520978155{margin:10px;width:50%;}.card-body.jsx-3520978155{padding:12px 20px;}@media only screen and (max-width:768px){.card-details-holder.jsx-3520978155{width:100%;}}</style><style id="__jsx-2139234697">.details-holder.jsx-2139234697{margin:30px 15px 15px 15px;padding:15px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}@media only screen and (max-width:768px){.details-holder.jsx-2139234697{margin:30px 5px 5px 5px;padding:5px;}}</style></head><body><div id="__next"><div class="jsx-2139234697"><div class="jsx-2139234697 details-holder"><div class="jsx-4010602164 compare-models-holder"></div><div class="jsx-3520978155 card-details-holder"><div class="jsx-3520978155 card"><div class="jsx-3520978155 card-body"><div class="jsx-4034635363 title-holder"><div class="jsx-4034635363 left-content"><img src="/arrow-right.png" class="jsx-4034635363"/><span class="jsx-4034635363">ACURA CL</span></div><span class="jsx-4034635363">2 generations</span></div></div></div></div><div class="jsx-3520978155 card-details-holder"><div  ...

# %%
script_id = "__NEXT_DATA__"  
response = requests.get(url)
soup = BeautifulSoup(response.content, 'html.parser')
script_element = soup.find("script", id=script_id)
script_content = script_element.text if script_element else None
data = re.findall(r'{.*}', script_content) if script_content else None
if data:
    print(data)
else:
    print("No data found or script element not found.")
# Out:
# ['{"dataManager":"[]","props":{"pageProps":{"carDetails":[{"_id":"601f068602038714fca4707c","name":"ACURA CL","url":"https://www.autoevolution.com/acura/cl/","carIndex":0,"generations":[{"models":[{"name":"ACURA CL 3.2 Type S","data":{"_id":"64a98526f917b000088049b7","consumption":{"_id":"64a98526f917b000088049b8","city":"19 mpg US (12.4 L/100Km)","highway":"29 mpg US (8.1 L/100Km)","combined":"23 mpg US (10.2 L/100Km)"},"dimensions":{"length":"192 in (4877 mm)","width":"70.6 in (1793 mm)","height":"53.3 in (1354 mm)"},"displacement":"3210 cm3","tiresize":"P215/50 R17","wheelbase":"106.9 in (2715 mm)","groundClearance":"6.2 in (157 mm)","cargo":"13.6 cuFT (385 L)","weight":"3510 lbs (1592 kg)"}},{"name":"ACURA CL 3.2L 5AT (225 HP)","data":{"_id":"64a98526f917b000088049b5","consumption":{"_id":"64a98526f917b000088049b6","city":"17 mpg US (13.8 L/100Km)","highway":"27 mpg US (8.7 L/100Km)","combined":"21 mpg US (11.2 L/100Km)"},"dimensions":{"length":"192 in (4877 mm)","width":"70.6 in (1793 mm)","height":"55.5 in (1410 mm)"},"displacement":"3210 cm3","tiresize":"P205/60 R16 91V ","wheelbase":"106.9 in (2715 mm)","groundClearance":"6.2 in (157 mm)","cargo":"13.6 cuFT (385 L)","weight":"3470 lbs (1574 kg)"}}],"year":"2001 - 2004|CL|The s","url":"https://www.autoevolution.com/cars/acura-cl-2001.html#aeng_acura-cl-2001-32-type-s"},{"models":[{"name":"ACURA CL 2.2L 5MT (145 HP)","data":{"_id":"64a98526f917b000088049b3","consumption":{"_id":"64a98526f917b000088049b4","city":"25 mpg US (9.4 L/100Km)","highway":"32 mpg US (7.4 L/100Km)","combined":"28 mpg US (8.4 L/100Km)"},"dimensions":{"length":"190 in (4826 mm)","width":"70.1 in (1781 mm)","height":"54.7 in (1389 mm)"},"displacement":"2156 cm3","tiresize":"P205/55 R16","wheelbase":"106.9 in (2715 mm)","groundClearance":"4.3 in (109 mm)","cargo":"12 cuFT (340 L)","weight":"3009 lbs (1365 kg)"}},{"name":"ACURA CL 3.0L V6 4AT (200 HP)","data":{"_id":"64a98526f917b000088049b1","consumption":{"_id":"64a98526f917b000088049b2","city":"20 mpg US (11.8 L/100Km)","highway":"28 mpg US (8.4 L/100Km)"},"dimensions":{"length":"190 in (4826 mm)","width":"70.1 in (1781 mm)","height":"54.7 in (1389 mm)"},"displacement":"2997 cm3","tiresize":"P205/55 R16 ","wheelbase":"106.9 in (2715 mm)","groundClearance":"4.3 in (109 mm)","cargo":"12 cuFT (340 L)","weight":"3219 lbs (1460 kg)"}}],"year":"1997 - 2001|CL|Acura","url":"https://www.autoevolution.com/cars/acura-cl-1997.html#aeng_acura-cl-1997-22"}]},{"_id":"601f067402038714fca47079","name":"ACURA ILX","url":"https://www.autoevolution.com/acura/ilx/","carIndex":0,"generations":[{"models":[{"name":"ACURA ILX 2.4L 16V i-VTEC 8AT (201 HP)","data":{"_id":"64a98526f917b00008804a03","consumption":{"_id":"64a98526f917b00008804a04","city":"24 mpg US (9.8 L/100Km)","highway":"34.1 mpg US (6.9 L/100Km)","combined":"28 mpg US (8.4 L/100Km)"},"dimensions":{"length":"181.9 in (4620 mm)","width":"70.6 in (1793 mm)","height":"55.6 in (1412 mm)"},"displacement":"2354 cm3","tiresize":"P215/45 R17","wheelbase":"105.1 in (2670 mm)","groundClearance":"5.3 in (135 mm)","cargo":"12.3 cuFT (348 L)","weight":"3093 lbs (1403 kg)"}}],"year":"2018 - Present|ILX|The f","url":"https://www.autoevolution.com/cars/acura-ilx-2018.html#aeng_acura-ilx-2018-24l-16v-i-vtec-8at-201-hp"},{"models":[{"name":"ACURA ILX 2.4L 8AT (201 HP)","data":{"_id":"64a98526f917b00008804a01","consumption":{"_id":"64a98526f917b00008804a02","city":"25 mpg US (9.4 L/100Km)","highway":"35.1 mpg US (6.7 L/100Km)","combined":"29 mpg US (8.1 L/100Km)"},"dimensions":{"length":"181.9 in (4620 mm)","width":"70.6 in (1793 mm)","height":"55.6 in (1412 mm)"},"displacement":"2354 cm3","tiresize":"P215/45 R17","wheelbase":"105.1 in (2670 mm)","groundClearance":"5.3 in (135 mm)","cargo":"12.3 cuFT (348 L)","weight":"3093 lbs (1403 kg)"}}],"year":"2016 - 2018|ILX|The s","url":"https://www.autoevolution.com/cars/acura-ilx-2016.html#aeng_acura-ilx-2016-24-8at-201-hp"},{"models":[{"name":"ACURA ILX 2.0L 5AT (150 HP)","data":{"_ ...
